# %%
import numpy as np
import pandas as pd 
from matplotlib import pyplot as plt
import seaborn as sns
from IPython.display import display, HTML
# %matplotlib inline

# %% [markdown]
# # HIPPOCAMPUS
# _______________________________________________________________________________________________

# %% [markdown]
# ## ALL TEMPORAL

# %%
cat_list = ['left temporal', 'bilateral temporal','right temporal']
original_data = pd.read_csv('data_09-15.csv')
temporal_data = original_data.loc[original_data['Type'].isin(cat_list)]

# %%
sns.set_style("darkgrid")
type_palette = sns.diverging_palette(255, 133, l=60, n=3, center="dark")
plt.figure(figsize=(12,9))
plt.title("Asymmetry - All TLE patients")
ax = sns.boxplot(x='Type', y='Hippocampus LI', data=temporal_data, order=cat_list, palette=type_palette, linewidth=1.2, saturation=0.7)
ax = sns.swarmplot(x='Type', y='Hippocampus LI', data=temporal_data, color=".25", order=cat_list)
ax.set_ylim(-1,1.03)
ax.hlines(y=0,xmin=-1,xmax=3, linestyle='dashed')

# %%
print("n=" + str(len(temporal_data)))
# Out:
# n=28

# %% [markdown]
# ## YES and MAYBE mTLE

# %%
# Filter yes and maybe mTLE
mtl_list = ['Yes','Maybe']
ym_mTLE_data = temporal_data.loc[original_data['MTL'].isin(mtl_list)]


sns.set_style("darkgrid")
type_palette = sns.diverging_palette(255, 133, l=60, n=3, center="dark")
plt.figure(figsize=(12,9))
plt.title("Asymmetry - Confirmed and 'possible' mTLE patients")
ax = sns.boxplot(x='Type', y='Hippocampus LI', data=ym_mTLE_data, order=cat_list, palette=type_palette, linewidth=1.2, saturation=0.7)
ax = sns.swarmplot(x='Type', y='Hippocampus LI', data=ym_mTLE_data, color=".25", order=cat_list)
ax.set_ylim(-1,1.03)
ax.hlines(y=0,xmin=-1,xmax=3, linestyle='dashed')

# %%
print("n="+ str(len(ym_mTLE_data)))
# Out:
# n=22

# %% [markdown]
# ## YES mTLE

# %%
# Filter yes and maybe mTLE
mtl_list = ['Yes']
mTLE_data = temporal_data.loc[original_data['MTL'].isin(mtl_list)]


sns.set_style("darkgrid")
type_palette = sns.diverging_palette(255, 133, l=60, n=3, center="dark")
plt.figure(figsize=(12,9))
plt.title("Asymmetry - Confirmed mTLE patients")
# ax = sns.barplot(x='Type', y='Hippocampus LI', data=df6, order=cat_list, palette=type_palette)
ax = sns.boxplot(x='Type', y='Hippocampus LI', data=mTLE_data, order=cat_list, palette=type_palette, linewidth=1.2, saturation=0.7)
ax = sns.swarmplot(x='Type', y='Hippocampus LI', data=mTLE_data, color=".25", order=cat_list)
ax.set_ylim(-1,1.03)
ax.hlines(y=0,xmin=-1,xmax=3, linestyle='dashed')

# %%
print("n=" + str(len(mTLE_data)))
# Out:
# n=12

# %%
def create_plot(cat_list_list, roi_list, bw):
    palette = ['black']
    clr_palette = sns.color_palette(palette)

    fig, axes = plt.subplots(1,3, figsize=(18, 6), sharey=True)
    if len(roi_list) == 2:
        fig.suptitle('{} and {} subject-wise comparison'.format(roi_list[0], roi_list[1]))
    if len(roi_list) == 3:
        fig.suptitle('{}, {}, and {} subject-wise comparison'.format(roi_list[0], roi_list[1], roi_list[2]))
        
    for catno in range(0, len(cat_list_list)):
        cat_list = cat_list_list[catno]
        df = original_data.loc[original_data['Type'].isin(cat_list)]
        regions_df = df[roi_list]# axes[0].plot(roi_list, )
        
        if cat_list[0] == 'left temporal':
            pheno = 'Left TLE'
        elif cat_list[0] == 'bilateral temporal':
            pheno = 'Bilateral TLE'
        elif cat_list[0] == 'right temporal':
            pheno = 'Right TLE'
        else:
            pheno = 'unlabeled phenotype'

        for index, row in regions_df.iterrows():
            row_list = list(row)
            position_list = list(np.linspace(len(row_list)/10,len(row_list)-.5, num=len(row_list),endpoint=False))
            if bw:
                axes[catno].plot(position_list,row_list, 'o-', color='gray', mfc='black',mec='black',lw=1, markersize=5)
            else:
                axes[catno].plot(position_list,row_list, 'o-', lw=1, markersize=5)
            axes[catno].set_xlabel(pheno)
            axes[catno].set_ylabel('Laterality Index')
            axes[catno].set_xlim([0.1,len(row_list)-1])
            axes[catno].set_ylim([-1.05,1.05])
            axes[catno].set_xticks(position_list)
            axes[catno].set_xticklabels(roi_list)

        axes[catno].hlines(y=0,xmin=0,xmax=len(position_list)-1, linestyle='dashed')
            
    return fig

# %%
cat_list_list = [['left temporal'], ['bilateral temporal'], ['right temporal']]
roi_list1 = ['Hippocampus LI','mTL LI']
roi_list2 = ['Hippocampus LI', 'mTL LI', 'Parahippocampal LI']

# font = {'family' : 'normal',
#         'weight' : 'bold',
#         'size'   : 12}
# import matplotlib
# matplotlib.rc('font', **font)

plt1 = create_plot(cat_list_list, roi_list1, True)
plt1.savefig('plots/hippo_mTL_comp.png', bbox_inches='tight')
plt2 = create_plot(cat_list_list, roi_list2, False)
plt2.savefig('plots/hippo_mTL_phg_comp.png', bbox_inches='tight')
# Out:
# /home/will/anaconda3/lib/python3.7/site-packages/matplotlib/font_manager.py:1241: UserWarning: findfont: Font family ['normal'] not found. Falling back to DejaVu Sans.
#   (prop.get_family(), self.defaultFamily[fontext]))
# /home/will/anaconda3/lib/python3.7/site-packages/matplotlib/font_manager.py:1241: UserWarning: findfont: Font family ['normal'] not found. Falling back to DejaVu Sans.
#   (prop.get_family(), self.defaultFamily[fontext]))
# /home/will/anaconda3/lib/python3.7/site-packages/matplotlib/font_manager.py:1241: UserWarning: findfont: Font family ['normal'] not found. Falling back to DejaVu Sans.
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
original_data[['subject','Type','Side','Hippocampus LI', 'mTL LI','Parahippocampal LI','Fusiform gyrus LI', 'Amygdala LI','MTL']]
# Out:
#    subject                                   Type       Side  Hippocampus LI  \
# 0     P048                  bilateral neocortical  Bilateral            0.00
# 1     P030                     bilateral temporal  Bilateral            0.67
# 2     P032                     bilateral temporal  Bilateral            0.06
# 3     P036                     bilateral temporal  Bilateral           -0.04
# 4     P046                     bilateral temporal  Bilateral            0.33
# 5     P067                     bilateral temporal  Bilateral            0.00
# 6     P068                     bilateral temporal  Bilateral            0.14
# 7     P078                     bilateral temporal  Bilateral            0.00
# 8     P087                     bilateral temporal  Bilateral            1.00
# 9     P091                     bilateral temporal  Bilateral            0.35
# 10    P039                       left neocortical       Left           -0.13
# 11    P047                       left neocortical       Left           -1.00
# 12    P054                       left neocortical       Left            0.08
# 13    P026                          left temporal       Left           -0.16
# 14    P027                          left temporal       Left            0.00
# 15    P028                          left temporal       Left           -0.30
# 16    P038                          left temporal       Left           -0.64
# 17    P041                          left temporal       Left           -0.79
# 18    P042                          left temporal       Left           -0.60
# 19    P044                          left temporal       Left           -0.16
# 20    P057                          left temporal       Left            0.00
# 21    P079                          left temporal       Left           -0.88
# 22    P080                          left temporal       Left            0.00
# 23    P082                          left temporal       Left           -0.50
# 24    P084                               temporal    unknown            0.50
# 25    P093                          left temporal       Left           -0.04
# 26    P094                          left temporal       Left           -0.29
# 27    P096                          left temporal       Left            1.00
# 28    P085  left temporal / possibly neocortical        Left            0.00
# 29    P050                    poor lateralization        NaN            0.00
# 30    P031                       poss neocortical      Right           -0.05
# 31    P086                          poss temporal  Bilateral           -0.08
# 32    P088                          poss temporal        NaN            0.00
# 33    P092                          poss temporal       Left            0.00
# 34    P064                      right neocortical      Right           -0.16
# 35    P077                      right neocortical      Right            0.00
# 36    P045                         right temporal      Right            1.00
# 37    P058                         right temporal      Right           -0.07
# 38    P061                         right temporal      Right            0.00
# 39    P075                         right temporal      Right            0.36
# 40    P095                         right temporal      Right            1.00
# 41    P083                               temporal       poor            0.02
# 42    P090                              temporal?        NaN           -0.18
# 43    P034                                unknown        NaN           -1.00
# 44    P055                                unknown        NaN           -0.87
# 45    P059                                unknown        NaN            0.00
# 46    P062                                unknown        NaN            1.00
# 47    P063                                unknown        NaN           -1.00
# 48    P066                                unknown        NaN            0.00
# 49    P069                                unknown        NaN           -0.10
# 50    P073                                unknown        NaN            1.00
#
#     mTL LI  Parahippocampal LI  Fusiform gyrus LI  Amygdala LI    MTL
# 0    -0.23                0.00              -0.57         0.00     No
# 1     0.24                0.21               0.17        -0.20  Maybe
# 2     0.18                0.10               0.29         0.03  Maybe
# 3    -0.08               -0.04              -0.13        -0.10    NaN
# 4     0.15                0.18               0.10         0.00  Maybe
# 5    -0.12               -0.07              -0.14        -1.00     No
# 6     0.13                0.02               0.23         1.00    NaN
# 7     0.11                0.18              -0.11         0.00    Yes
# 8     0.03                0.06              -0.08         0.50  Maybe
# 9     0.06               -0.13               0.07         0.41    Yes
# 10    0.03               -0.06               0.22         0.82    Yes
# 11    0.11                0.42               0.58        -0.71  Maybe
# 12    0.03                0.14               0.00         0.00    NaN
# 13   -0.01                0.10               0.04         0.02    Yes
# 14    0.33                0.09               1.00         0.00    Yes
# 15    0.31                0.33               0.55         0.20  Maybe
# 16    0.21                0.24               0.41         0.06  Maybe
# 17   -0.11               -0.03               0.16        -1.00    NaN
# 18   -0.14               -0.23              -0.10         0.00    Yes
# 19    0.01                0.05               0.07         0.04    Yes
# 20    0.27                0.07               0.33         0.00   Yes
# 21   -0.11               -0.07               0.16        -1.00  Maybe
# 22    0.26                0.47               0.13         0.00  Maybe
# 23   -0.07                0.02              -0.18         0.00  Maybe
# 24    0.00                0.13              -0.22         1.00    NaN
# 25    0.02               -0.01               0.10         0.35    Yes
# 26   -0.07               -0.11               0.04        -0.69    Yes
# 27    0.38                0.26               0.53         0.00    Yes
# 28    0.00               -0.20               0.00         0.00    NaN
# 29    0.09                0.09               0.05         0.00    NaN
# 30   -0.02                0.09              -0.04         0.10    NaN
# 31   -0.01               -0.03               0.07        -0.33    NaN
# 32    0.00               -0.19               0.20         0.00    NaN
# 33    0.33                1.00               0.30         0.00    Yes
# 34   -0.07               -0.08               0.04        -0.50    NaN
# 35   -0.09               -0.20               0.00         0.00  Maybe
# 36    0.61                0.60               0.34         1.00  Maybe
# 37   -0.02               -0.12               0.15        -0.09    Yes
# 38    0.50                0.60               1.00         0.00    Yes
# 39    0.10               -0.11               0.00         0.40    NaN
# 40    0.12                0.00               0.13         0.00    Yes
# 41   -0.08               -0.06              -0.16        -0.14    NaN
# 42   -0.12               -0.07              -0.14         0.40    NaN
# 43   -0.06               -0.18               0.09        -1.00  Maybe
# 44   -0.38               -0.29              -0.30        -0.75    NaN
# 45    0.25                0.44               0.17         0.00    NaN
# 46    0.44                0.04               0.57         1.00    NaN
# 47    0.14               -0.08               0.54         0.00    NaN
# 48    0.09                0.18               0.02         0.00    NaN
# 49   -0.16                0.02              -0.30        -0.27    NaN
# 50    0.56                0.24               0.63         1.00    NaN

# %% [markdown]
# # Medial Temporal Lobe
# _______________________________________________________________________________________________

# %%
sns.set_style("darkgrid")
type_palette = sns.diverging_palette(255, 133, l=60, n=3, center="dark")
plt.figure(figsize=(12,9))
plt.title("Asymmetry - All TLE patients")
ax = sns.boxplot(x='Type', y='mTL LI', data=temporal_data, order=cat_list, palette=type_palette, linewidth=1.2, saturation=0.7)
ax = sns.swarmplot(x='Type', y='mTL LI', data=temporal_data, color=".25", order=cat_list)
ax.set_ylim(-1,1)
ax.hlines(y=0,xmin=-1,xmax=3, linestyle='dashed')

# %%
print("n=" + str(len(temporal_data)))
# Out:
# n=28

# %% [markdown]
# ## YES and MAYBE mTLE

# %%
# Filter yes and maybe mTLE
sns.set_style("darkgrid")
type_palette = sns.diverging_palette(255, 133, l=60, n=3, center="dark")
plt.figure(figsize=(12,9))
plt.title("Asymmetry - Confirmed and 'possible' mTLE patients")
ax = sns.boxplot(x='Type', y='mTL LI', data=ym_mTLE_data, order=cat_list, palette=type_palette, linewidth=1.2, saturation=0.7)
ax = sns.swarmplot(x='Type', y='mTL LI', data=ym_mTLE_data, color=".25", order=cat_list)
ax.set_ylim(-1,1)
ax.hlines(y=0,xmin=-1,xmax=3, linestyle='dashed')

# %%
print("n="+ str(len(ym_mTLE_data)))
# Out:
# n=22

# %% [markdown]
# ## YES mTLE

# %%
# Filter yes and maybe mTLE
sns.set_style("darkgrid")
type_palette = sns.diverging_palette(255, 133, l=60, n=3, center="dark")
plt.figure(figsize=(12,9))
plt.title("Asymmetry - Confirmed mTLE patients")
ax = sns.boxplot(x='Type', y='mTL LI', data=mTLE_data, order=cat_list, palette=type_palette, linewidth=1.2, saturation=0.7)
ax = sns.swarmplot(x='Type', y='mTL LI', data=mTLE_data, color=".25", order=cat_list)
ax.set_ylim(-1,1)
ax.hlines(y=0,xmin=-1,xmax=3, linestyle='dashed')

# %%
print("n=" + str(len(mTLE_data)))
# Out:
# n=12

# %% [markdown]
# # Compiled figure

# %%
f, axes = plt.subplots(3, 2, figsize=(10, 10), sharex=True, sharey=True)

# Hippocampus LI        
sns.boxplot(x='Type', y='Hippocampus LI', data=temporal_data, order=cat_list, palette=type_palette, linewidth=1.2, saturation=0.7, ax=axes[0,0])
sns.swarmplot(x='Type', y='Hippocampus LI', data=temporal_data, color="maroon", order=cat_list, edgecolor="black", linewidth=.6,ax=axes[0,0])
        
sns.boxplot(x='Type', y='Hippocampus LI', data=ym_mTLE_data, order=cat_list, palette=type_palette, linewidth=1.2, saturation=0.7, ax=axes[1,0])
sns.swarmplot(x='Type', y='Hippocampus LI', data=ym_mTLE_data, color="maroon", order=cat_list, edgecolor="black", linewidth=.6,ax=axes[1,0])  
        
sns.boxplot(x='Type', y='Hippocampus LI', data=mTLE_data, order=cat_list, palette=type_palette, linewidth=1.2, saturation=0.7, ax=axes[2,0])
sns.swarmplot(x='Type', y='Hippocampus LI', data=mTLE_data, color="maroon", order=cat_list, edgecolor="black", linewidth=.6, ax=axes[2,0])  
    
# mTL LI    
sns.boxplot(x='Type', y='mTL LI', data=temporal_data, order=cat_list, palette=type_palette, linewidth=1.2, saturation=0.7, ax=axes[0,1])
sns.swarmplot(x='Type', y='mTL LI', data=temporal_data, color="maroon", order=cat_list, edgecolor="black", linewidth=.6,ax=axes[0,1])
        
sns.boxplot(x='Type', y='mTL LI', data=ym_mTLE_data, order=cat_list, palette=type_palette, linewidth=1.2, saturation=0.7, ax=axes[1,1])
sns.swarmplot(x='Type', y='mTL LI', data=ym_mTLE_data, color="maroon", order=cat_list, edgecolor="black", linewidth=.6,ax=axes[1,1])  
        
sns.boxplot(x='Type', y='mTL LI', data=mTLE_data, order=cat_list, palette=type_palette, linewidth=1.2, saturation=0.7, ax=axes[2,1])
sns.swarmplot(x='Type', y='mTL LI', data=mTLE_data, color="maroon", order=cat_list, edgecolor="black", linewidth=.6, ax=axes[2,1])  

for ax in axes:
    for a in ax:
        a.set_ylim(-1,1.1)
        a.hlines(y=0,xmin=-1,xmax=3, linestyle='dashed')
        a.set_xlabel("")
        
plt.savefig('plots/roi_analysis.svg')
